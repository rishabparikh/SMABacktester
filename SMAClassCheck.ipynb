# %%
from SMAbacktester import SMABacktester

# %%
tester= SMABacktester("SPY",1,200, "2000-01-01","2020-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (2.430122, 0.100967)

# %%
tester.plot_results()
