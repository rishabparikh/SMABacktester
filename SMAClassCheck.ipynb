# %%
from SMAbacktester import SMABacktester

# %%
tester= SMABacktester("ETSY",1,200, "2000-01-01","2020-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (3.255325, -2.453438)

# %%
tester.plot_results()
